# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# %%
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.hist(figsize = (20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'anaemia'}>,
#         <AxesSubplot:title={'center':'creatinine_phosphokinase'}>,
#         <AxesSubplot:title={'center':'diabetes'}>],
#        [<AxesSubplot:title={'center':'ejection_fraction'}>,
#         <AxesSubplot:title={'center':'high_blood_pressure'}>,
#         <AxesSubplot:title={'center':'platelets'}>,
#         <AxesSubplot:title={'center':'serum_creatinine'}>],
#        [<AxesSubplot:title={'center':'serum_sodium'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'smoking'}>,
#         <AxesSubplot:title={'center':'time'}>],
#        [<AxesSubplot:title={'center':'DEATH_EVENT'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
data['DEATH_EVENT'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['sex'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()
data = rs.fit_transform(data)
data = pd.DataFrame(data)

# %%
data.columns=['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'plateletes', 'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time', 'DEATH_EVENT']

# %%
data.head()
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  0.789474      0.0                  0.713212       0.0               -1.2
# 1 -0.263158      0.0                 16.350161       0.0                0.0
# 2  0.263158      0.0                 -0.223416       0.0               -1.2
# 3 -0.526316      1.0                 -0.298604       0.0               -1.2
# 4  0.263158      1.0                 -0.193340       1.0               -1.2
#
#    high_blood_pressure  plateletes  serum_creatinine  serum_sodium  sex  \
# 0                  1.0    0.032967               1.6     -1.166667  0.0
# 1                  0.0    0.014923               0.0     -0.166667  0.0
# 2                  0.0   -1.098901               0.4     -1.333333  0.0
# 3                  0.0   -0.571429               1.6      0.000000  0.0
# 4                  0.0    0.714286               3.2     -3.500000 -1.0
#
#    smoking      time  DEATH_EVENT
# 0      0.0 -0.853846          1.0
# ...

# %% [markdown]
# # Plotting  correlation between features for feature selection

# %%
corr = data.corr()
import seaborn as sns
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_f32f2_row0_col0,#T_f32f2_row1_col1,#T_f32f2_row2_col2,#T_f32f2_row3_col3,#T_f32f2_row4_col4,#T_f32f2_row5_col5,#T_f32f2_row6_col6,#T_f32f2_row7_col7,#T_f32f2_row8_col8,#T_f32f2_row9_col9,#T_f32f2_row10_col10,#T_f32f2_row11_col11,#T_f32f2_row12_col12{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f32f2_row0_col1,#T_f32f2_row4_col0,#T_f32f2_row5_col4,#T_f32f2_row12_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_f32f2_row0_col2{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_f32f2_row0_col3{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_f32f2_row0_col4,#T_f32f2_row5_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_f32f2_row0_col5{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_f32f2_row0_col6{
# ...

# %%
data_new = data.copy()
data_new = data_new.drop('smoking', axis=1)

# %% [markdown]
# # Train Test splitting

# %%
X = data.iloc[:, :12]
y = data['DEATH_EVENT']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=2)

# %%
y_train
# Out:
# 53     1.0
# 172    0.0
# 23     0.0
# 98     0.0
# 244    0.0
#       ...
# 75     1.0
# 22     1.0
# 72     1.0
# 15     1.0
# 168    0.0
# Name: DEATH_EVENT, Length: 239, dtype: float64

# %% [markdown]
# # Model creation and evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree  import DecisionTreeClassifier

# %%
KNclassifier = KNeighborsClassifier(n_neighbors=10)
SVclassifier = SVC(kernel='linear')
LGclassifier = LogisticRegression()
DTclassifier = DecisionTreeClassifier(max_depth=5)
RFclassifier = RandomForestClassifier(n_estimators=7, criterion='entropy', max_depth=10)
ABclassifier = AdaBoostClassifier()

# %%
KNclassifier.fit(X_train, y_train)
SVclassifier.fit(X_train, y_train)
LGclassifier.fit(X_train, y_train)
DTclassifier.fit(X_train, y_train)
RFclassifier.fit(X_train, y_train)
ABclassifier.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score

y_pred_knn = KNclassifier.predict(X_test)
y_pred_svc = SVclassifier.predict(X_test)
y_pred_lg = LGclassifier.predict(X_test)
y_pred_dt = DTclassifier.predict(X_test)
y_pred_rf = RFclassifier.predict(X_test)
y_pred_AB = ABclassifier.predict(X_test)

dict = {}
